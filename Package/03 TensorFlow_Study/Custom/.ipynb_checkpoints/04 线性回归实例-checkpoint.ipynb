# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = np.random.rand(100)
y_data = x_data * 0.1 + 0.2

plt.scatter(x_data, y_data)

b = tf.Variable(1.1)
k = tf.Variable(0.5)
y = k * x_data + b

loss = tf.reduce_mean(tf.square(y_data - y))
optimizer = tf.train.GradientDescentOptimizer(0.1)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for step in range(201):
        sess.run(train)
        if step % 20 == 0 and step != 0:
            plt.plot(x_data.tolist(), y.eval())
            print(step, sess.run([k, b]))
plt.show()
# Out:
# 20 [0.04127748, 0.23445731]
# 40 [0.05085396, 0.22704475]
# 60 [0.059490982, 0.2222873]
# 80 [0.066611685, 0.21836959]
# 100 [0.07248072, 0.21514057]
# 120 [0.077318095, 0.21247914]
# 140 [0.081305146, 0.21028556]
# 160 [0.08459136, 0.20847753]
# 180 [0.087299906, 0.20698735]
# 200 [0.08953234, 0.20575911]
